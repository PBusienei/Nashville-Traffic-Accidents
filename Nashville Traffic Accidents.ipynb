# %% [markdown]
# ## Load the libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline

# %% [markdown]
# ## Read the data and get an overview

# %%
car_accident0=pd.read_csv('data/Traffic_Accidents__2010_.csv', low_memory=False)
car_accident1=pd.read_csv('data/Traffic_Accidents__2011_.csv', low_memory=False)
car_accident2=pd.read_csv('data/Traffic_Accidents__2012_.csv', low_memory=False)
car_accident3=pd.read_csv('data/Traffic_Accidents__2013_.csv', low_memory=False)
car_accident4=pd.read_csv('data/Traffic_Accidents__2014_.csv', low_memory=False)
car_accident5=pd.read_csv('data/Traffic_Accidents__2015_.csv', low_memory=False)
car_accident6=pd.read_csv('data/Traffic_Accidents__2016_.csv', low_memory=False)
car_accident7=pd.read_csv('data/Traffic_Accidents__2017_.csv', low_memory=False)
car_accident8=pd.read_csv('data/Traffic_Accidents__2018_.csv', low_memory=False)
car_accident9=pd.read_csv('data/Traffic_Accidents__2019_.csv', low_memory=False)
car_accident20=pd.read_csv('data/Traffic_Accidents__2020_.csv',low_memory=False)

# %%
car_accident0.shape
# Out:
# (22276, 29)

# %%
# Save the number of rows columns as a tuple
rows_and_cols = car_accident0.shape
print('There are {} rows and {} columns.\n'.format(
    rows_and_cols[0], rows_and_cols[1]))
# Out:
# There are 22276 rows and 29 columns.

# %%
# Generating an overview of the DataFrame
car_acc_information = car_accident0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22276 entries, 0 to 22275
# Data columns (total 29 columns):
# Accident Number                    22276 non-null int64
# Date and Time                      22276 non-null object
# Number of Motor Vehicles           22258 non-null float64
# Number of Injuries                 22273 non-null float64
# Number of Fatalities               22269 non-null float64
# Property Damage                    22274 non-null object
# Hit and Run                        22274 non-null object
# Reporting Officer                  22274 non-null object
# Collision Type Code                22262 non-null float64
# Collision Type Description         22262 non-null object
# Weather Code                       22273 non-null float64
# Weather Description                22273 non-null object
# Illumination Code                  22271 non-null float64
# Illumination Description           22271 non-null object
# Harmful Code                       22275 non-null object
# Harmful Description                22275 non-null object
# Street Address                     22276 non-null object
# City                               18957 non-null object
# State                              20887 non-null object
# ZIP                                19838 non-null object
# RPA                                17414 non-null float64
# Precinct                           17813 non-null object
# Latitude                           18029 non-null float64
# Longitude                          18029 non-null float64
# Mapped Location                    18029 non-null object
# Davidson County Border (GIS)       18026 non-null float64
# Service Districts (GIS)            18026 non-null float64
# Council District Outlines (GIS)    18026 non-null float64
# Zip Codes (GIS)                    18026 non-null float64
# dtypes: float64(13), int64(1), object(15)
# memory usage: 4.9+ MB

# %%
# Display the first five rows of the DataFrame
car_accident0.head(2)
# Out:
#    Accident Number           Date and Time  Number of Motor Vehicles  \
# 0       2010056563  01/01/2010 10:10:00 PM                       1.0
# 1       2010062168  01/05/2010 05:25:00 PM                       2.0
#
#    Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 0                 1.0                   0.0               N           N
# 1                 0.0                   0.0               N           Y
#
#   Reporting Officer  Collision Type Code  \
# 0            633368                  0.0
# 1            430440                  1.0
#
#                 Collision Type Description  ...  ZIP RPA  Precinct Latitude  \
# 0  NOT COLLISION W/MOTOR VEHICLE-TRANSPORT  ...  NaN NaN       NaN      NaN
# 1                                 REAR END  ...  NaN NaN       NaN      NaN
#
#   Longitude Mapped Location Davidson County Border (GIS)  \
# 0       NaN             NaN                          NaN
# 1       NaN             NaN                          NaN
#
#   Service Districts (GIS) Council District Outlines (GIS) Zip Codes (GIS)
# 0                     NaN                             NaN             NaN
# 1                     NaN                             NaN             NaN
#
# [2 rows x 29 columns]

# %%
car_accident1.head(2)
# Out:
#    Accident Number           Date and Time  Number of Motor Vehicles  \
# 0      20110001426  01/01/2011 07:30:00 PM                       2.0
# 1      20110005142  01/03/2011 03:46:00 PM                       2.0
#
#    Number of Injuries  Number of Fatalities Property Damage Hit and Run  \
# 0                 2.0                   0.0               N           N
# 1                 0.0                   0.0               N           Y
#
#   Reporting Officer  Collision Type Code      Collision Type Description  ...  \
# 0            714626                  4.0                           ANGLE  ...
# 1            224368                  6.0  SIDESWIPE - OPPOSITE DIRECTION  ...
#
#        ZIP     RPA  Precinct Latitude Longitude Mapped Location  \
# 0  37115.0  2007.0    MADISO      NaN       NaN             NaN
# 1      NaN     NaN       NaN      NaN       NaN             NaN
#
#   Davidson County Border (GIS) Service Districts (GIS)  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
#
#   Council District Outlines (GIS)  Zip Codes (GIS)
# 0                             NaN              NaN
# 1                             NaN              NaN
#
# [2 rows x 29 columns]

# %%
# compile the list of dataframes to be merged
data_frames = [car_accident0, car_accident1, car_accident2,car_accident3, car_accident4, car_accident5, car_accident6, car_accident7, car_accident8, car_accident9, car_accident20 ]

# %%
car_accidents_2010_2020 = pd.concat([car_accident0, car_accident1, car_accident2,car_accident3, car_accident4, car_accident5, car_accident6, car_accident7, car_accident8, car_accident9, car_accident20], sort=True)
car_accidents_2010_2020.head(2)
# Out:
#   Accident Number City  Collision Type  Collision Type Code  \
# 0      2010056563  NaN             NaN                  0.0
# 1      2010062168  NaN             NaN                  1.0
#
#                 Collision Type Description  Council District Outlines (GIS)  \
# 0  NOT COLLISION W/MOTOR VEHICLE-TRANSPORT                              NaN
# 1                                 REAR END                              NaN
#
#             Date and Time  Davidson County Border (GIS) Harmful Code  \
# 0  01/01/2010 10:10:00 PM                           NaN            8
# 1  01/05/2010 05:25:00 PM                           NaN        12;14
#
#   Harmful Code Description  ... RPA Reporting Officer Service Districts (GIS)  \
# 0                      NaN  ... NaN            633368                     NaN
# 1                      NaN  ... NaN            430440                     NaN
#
#   State            Street Address  Weather Weather Code  \
# 0   NaN  BELL RD & SAXONY LAKE DR      NaN          1.0
# 1   NaN        2521 PARK GREEN LA      NaN          1.0
#
#      Weather Description  ZIP Zip Codes (GIS)
# 0  NO ADVERSE CONDITIONS  NaN             NaN
# 1  NO ADVERSE CONDITIONS  NaN             NaN
#
# [2 rows x 36 columns]

# %%
print('There are {} accidents in the data'.format(len(car_accidents_2010_2020)))
# Out:
# There are 591283 accidents in the data

# %%
car_accidents_2010_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 591283 entries, 0 to 297956
# Data columns (total 36 columns):
# Accident Number                    591283 non-null object
# City                               578146 non-null object
# Collision Type                     156042 non-null float64
# Collision Type Code                435005 non-null float64
# Collision Type Description         589999 non-null object
# Council District Outlines (GIS)    58708 non-null float64
# Date and Time                      591212 non-null object
# Davidson County Border (GIS)       58708 non-null float64
# Harmful Code                       435190 non-null object
# Harmful Code Description           363876 non-null object
# Harmful Codes                      156091 non-null object
# Harmful Codes Description          155059 non-null object
# Harmful Description                67962 non-null object
# Hit and Run                        591205 non-null object
# Illumination                       155849 non-null float64
# Illumination Code                  434734 non-null float64
# Illumination Description           590533 non-null object
# Latitude                           565958 non-null float64
# Longitude                          565946 non-null float64
# Mapped Location                    530466 non-null object
# New Georeferenced Column           34548 non-null object
# Number of Fatalities               590982 non-null float64
# Number of Injuries                 591104 non-null float64
# Number of Motor Vehicles           591008 non-null float64
# Precinct                           561380 non-null object
# Property Damage                    250937 non-null object
# RPA                                563072 non-null float64
# Reporting Officer                  591089 non-null object
# Service Districts (GIS)            58708 non-null float64
# State                              586062 non-null object
# Street Address                     590959 non-null object
# Weather                            155845 non-null float64
# Weather Code                       434596 non-null float64
# Weather Description                590441 non-null object
# ZIP                                572234 non-null object
# Zip Codes (GIS)                    58708 non-null float64
# dtypes: float64(16), object(20)
# memory usage: 166.9+ MB

# %%
car_accidents_2010_2020['Collision Type'].value_counts(normalize=True).sort_index().plot.bar()
plt.grid()
plt.title('collision Type')
plt.xlabel('Collision Type')
plt.ylabel('Fraction');

# %%
car_accidents_2010_2020['Collision Type'].value_counts().plot.bar()
plt.grid()
plt.title('collision Type')
plt.xlabel('Collision Type')
plt.ylabel('Fraction');

# %%
car_accidents_2010_2020['Collision Type Code'].value_counts(normalize=True).sort_index().plot.bar()
plt.grid()
plt.title('collision Type Code')
plt.xlabel('Collision Type Code')
plt.ylabel('Fraction');

# %%
car_accidents_2010_2020['Collision Type Description'].value_counts(normalize=True).sort_index().plot.bar()
plt.grid()
plt.title('Collision Type Description')
plt.xlabel('Collision Type Description')
plt.ylabel('Fraction');

# %%
car_accidents_2010_2020['Collision Type Description'].value_counts().plot.bar()
plt.grid()
plt.title('Collision Type Description')
plt.xlabel('Collision Type Description')
plt.ylabel('Total count');

# %%
bool_cols = [col for col in car_accidents_2010_2020.columns if car_accidents_2010_2020[col].dtype ==np.dtype('bool')]
booldf = car_accidents_2010_2020[bool_cols]
not_one_hot = booldf[booldf.sum(axis=1) > 1]
print('There are {} non one hot metadata rows, which are {:.1f}% of the data'.format(len(not_one_hot),100*len(not_one_hot)/len(car_accidents_2010_2020)))
# Out:
# There are 0 non one hot metadata rows, which are 0.0% of the data

# %%
car_accidents_2010_2020['DateTime'] = pd.to_datetime(car_accidents_2010_2020['Date and Time'])
car_accidents_2010_2020['date'] = car_accidents_2010_2020['DateTime'].dt.date
car_accidents_2010_2020['time'] = car_accidents_2010_2020['DateTime'].dt.time

# %%
car_accidents_2010_2020 = car_accidents_2010_2020.set_index('DateTime')
car_accidents_2010_2020.head(3)
# Out:
#                     Accident Number City  Collision Type  Collision Type Code  \
# DateTime
# 2010-01-01 22:10:00      2010056563  NaN             NaN                  0.0
# 2010-01-05 17:25:00      2010062168  NaN             NaN                  1.0
# 2010-01-06 12:50:00      2010065000  NaN             NaN                  1.0
#
#                                   Collision Type Description  \
# DateTime
# 2010-01-01 22:10:00  NOT COLLISION W/MOTOR VEHICLE-TRANSPORT
# 2010-01-05 17:25:00                                 REAR END
# 2010-01-06 12:50:00                                 REAR END
#
#                      Council District Outlines (GIS)           Date and Time  \
# DateTime
# 2010-01-01 22:10:00                              NaN  01/01/2010 10:10:00 PM
# 2010-01-05 17:25:00                              NaN  01/05/2010 05:25:00 PM
# 2010-01-06 12:50:00                              NaN  01/06/2010 12:50:00 PM
#
#                      Davidson County Border (GIS) Harmful Code  \
# DateTime
# 2010-01-01 22:10:00                           NaN            8
# 2010-01-05 17:25:00                           NaN        12;14
# 2010-01-06 12:50:00                           NaN           12
#
#                     Harmful Code Description  ... Reporting Officer  \
# DateTime                                      ...
# 2010-01-01 22:10:00                      NaN  ...            633368
# 2010-01-05 17:25:00                      NaN  ...            430440
# 2010-01-06 12:50:00                      NaN  ...            224486
#
#                     Service Districts (GIS) State  \
# DateTime
# 2010-01-01 22:10:00                     NaN   NaN
# 2010-01-05 17:25:00                     NaN   NaN
# 2010-01-06 12:50:00                     NaN   NaN
#
#                                    Street Address  Weather  Weather Code  \
# DateTime
# 2010-01-01 22:10:00      BELL RD & SAXONY LAKE DR      NaN           1.0
# 2010-01-05 17:25:00            2521 PARK GREEN LA      NaN           1.0
# 2010-01-06 12:50:00  NOLENSVILLE PKE & HAYWOOD LA      NaN           1.0
#
#                        Weather Description  ZIP  Zip Codes (GIS)        date
# DateTime
# 2010-01-01 22:10:00  NO ADVERSE CONDITIONS  NaN              NaN  2010-01-01
# 2010-01-05 17:25:00  NO ADVERSE CONDITIONS  NaN              NaN  2010-01-05
# 2010-01-06 12:50:00  NO ADVERSE CONDITIONS  NaN              NaN  2010-01-06
#
# [3 rows x 37 columns]

# %%
years = ['2010','2011','2012','2013', '2014', '2015', '2016', '2017', '2018', '2019']
fig, _ = plt.subplots(1,10, figsize=(44,8), sharex='all', sharey='all')

fig.suptitle('Acccidents by month for Different Years')
plt.xlabel('month')
plt.ylabel('Accidents')
for i, year in enumerate(years,1):
    plt.subplot(1,10,i)
    sample = car_accidents_2010_2020.loc[year]['Accident Number'].resample('M').count()
    sample.plot()
    plt.ylim(0,8000)
    plt.title('Accidents, {} count'.format(text))
    plt.xlabel('Year')
    plt.ylabel('Accident Count');

# %%
car_accidents_2010_2020['Weekday'] = car_accidents_2010_2020.index.weekday_name
weekday = car_accidents_2010_2020.groupby('Weekday')['Accident Number'].count()
weekday = weekday/weekday.sum()
dayOfWeek=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
weekday[dayOfWeek].plot.bar()
plt.title('Acccidents by Weekday')
plt.xlabel('Weekday')
plt.ylabel('Accidents');

# %% [markdown]
# Most common day with high number of crashes "Friday". Hence they are probably approximate, and probably correspond to the time it took to resolve the accident rather than the accident itself

# %%
years = ['2010','2011','2012','2013', '2014', '2015', '2016', '2017', '2018', '2019']
fig, _ = plt.subplots(1,10,figsize=(21,7), sharex='all', sharey='all')

fig.suptitle('Acccidents by Weekday for Different Years')
plt.xlabel('Weekday')
plt.ylabel('Accidents')
for i, year in enumerate(years,1):
    weekday = car_accidents_2010_2020.loc[year].groupby('Weekday')['Accident Number'].count()
    weekday = weekday/weekday.sum()
    dayOfWeek=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
    plt.subplot(1,10,i)
    plt.title(year)
    weekday[dayOfWeek].plot.bar()
